# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = r'C:\Users\moiez\OneDrive\Desktop\pokemon_data.csv'

# %%
df = pd.read_csv(path)
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
# find row where generation is 5
df[df["Generation"] == 5]
# Out:
#        #                     Name   Type 1    Type 2   HP  Attack  Defense  \
# 553  494                  Victini  Psychic      Fire  100     100      100
# 554  495                    Snivy    Grass       NaN   45      45       55
# 555  496                  Servine    Grass       NaN   60      60       75
# 556  497                Serperior    Grass       NaN   75      75       95
# 557  498                    Tepig     Fire       NaN   65      63       45
# ..   ...                      ...      ...       ...  ...     ...      ...
# 713  647     KeldeoOrdinary Forme    Water  Fighting   91      72       90
# 714  647     KeldeoResolute Forme    Water  Fighting   91      72       90
# 715  648       MeloettaAria Forme   Normal   Psychic  100      77       77
# 716  648  MeloettaPirouette Forme   Normal  Fighting  100     128       90
# 717  649                 Genesect      Bug     Steel   71     120       95
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# find a row where speed is maximum
max(df["Speed"])
# Out:
# 180

# %%
max = df["Speed"].max()
max
# Out:
# 180

# %%
# find a row where speed is minimum
min(df["Speed"])
# Out:
# 5

# %%
# find the rows where attack is equal to average
df["Attack"].mean()
# Out:
# 79.00125

# %%
int(df["Attack"].mean())
# Out:
# 79

# %%
avg = int(df["Attack"].mean())
avg
# Out:
# 79

# %%
df[df["Attack"] == avg]
# Out:
#        #                 Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 459  413  WormadamSandy Cloak    Bug  Ground  60      79      105       59
#
#      Sp. Def  Speed  Generation  Legendary
# 459       85     36           4      False

# %%
# find all pokemon where type 1 is water
df["Type 1"] == "Water"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Name: Type 1, Length: 800, dtype: bool

# %%
df[df["Type 1"] == "Water"]
# Out:
#        #                     Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 9      7                 Squirtle  Water    NaN  44      48       65       50
# 10     8                Wartortle  Water    NaN  59      63       80       65
# 11     9                Blastoise  Water    NaN  79      83      100       85
# 12     9  BlastoiseMega Blastoise  Water    NaN  79     103      120      135
# 59    54                  Psyduck  Water    NaN  50      52       48       65
# ..   ...                      ...    ...    ...  ..     ...      ...      ...
# 724  656                  Froakie  Water    NaN  41      56       40       62
# 725  657                Frogadier  Water    NaN  54      63       52       83
# 726  658                 Greninja  Water   Dark  72      95       67      103
# 762  692                Clauncher  Water    NaN  50      53       62       58
# 763  693                Clawitzer  Water    NaN  71      73       88      120
#
# ...

# %%
# Find all rows where type 1 is rock and speed is greater than 100
df["Type 1"]
# Out:
# 0        Grass
# 1        Grass
# 2        Grass
# 3        Grass
# 4         Fire
#         ...
# 795       Rock
# 796       Rock
# 797    Psychic
# 798    Psychic
# 799       Fire
# Name: Type 1, Length: 800, dtype: object

# %%
df["Type 1"] == "Rock"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795     True
# 796     True
# 797    False
# 798    False
# 799    False
# Name: Type 1, Length: 800, dtype: bool

# %%
df[df["Type 1"] == "Rock"]
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 80    74                    Geodude   Rock    Ground   40      80      100
# 81    75                   Graveler   Rock    Ground   55      95      115
# 82    76                      Golem   Rock    Ground   80     120      130
# 103   95                       Onix   Rock    Ground   35      45      160
# 149  138                    Omanyte   Rock     Water   35      40      100
# 150  139                    Omastar   Rock     Water   70      60      125
# 151  140                     Kabuto   Rock     Water   30      80       90
# 152  141                   Kabutops   Rock     Water   60     115      105
# 153  142                 Aerodactyl   Rock    Flying   80     105       65
# 154  142  AerodactylMega Aerodactyl   Rock    Flying   80     135       85
# 200  185                  Sudowoodo   Rock       NaN   70     100      115
# ...

# %%
rock_speed = df[df["Type 1"] == "Rock"]

# %%
rock_speed["Speed"]
# Out:
# 80      20
# 81      35
# 82      45
# 103     70
# 149     35
# 150     55
# 151     55
# 152     80
# 153    130
# 154    150
# 200     30
# 265     41
# 266     51
# 267     61
# 268     71
# 323     30
# 369     70
# 370     70
# 377     23
# 378     43
# 379     75
# 380     45
# 414     50
# 453     58
# 454     58
# 455     30
# 456     30
# 486     10
# 528     40
# 583     15
# 584     20
# 585     25
# 627     70
# 628    110
# 700    108
# 758     50
# 759     68
# 766     48
# 767     71
# 768     46
# 769     58
# 773     50
# 795     50
# 796    110
# Name: Speed, dtype: int64

# %%
rock_speed["Speed"] >= 100
# Out:
# 80     False
# 81     False
# 82     False
# 103    False
# 149    False
# 150    False
# 151    False
# 152    False
# 153     True
# 154     True
# 200    False
# 265    False
# 266    False
# 267    False
# 268    False
# 323    False
# 369    False
# 370    False
# 377    False
# 378    False
# 379    False
# 380    False
# 414    False
# 453    False
# 454    False
# 455    False
# 456    False
# 486    False
# 528    False
# 583    False
# 584    False
# 585    False
# 627    False
# 628     True
# 700     True
# 758    False
# 759    False
# 766    False
# 767    False
# 768    False
# 769    False
# 773    False
# 795    False
# 796     True
# Name: Speed, dtype: bool

# %%
rock_speed[rock_speed["Speed"] >= 100]
# Out:
#        #                       Name Type 1    Type 2  HP  Attack  Defense  \
# 153  142                 Aerodactyl   Rock    Flying  80     105       65
# 154  142  AerodactylMega Aerodactyl   Rock    Flying  80     135       85
# 628  567                   Archeops   Rock    Flying  75     140       65
# 700  639                  Terrakion   Rock  Fighting  91     129       90
# 796  719        DiancieMega Diancie   Rock     Fairy  50     160      110
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 153       60       75    130           1      False
# 154       70       95    150           1      False
# 628      112       65    110           5      False
# 700       72       90    108           5       True
# 796      160      110    110           6       True

# %%
# find all rows where type 1 is rock and type 2 is electric
df["Type 1"] == "Rock"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795     True
# 796     True
# 797    False
# 798    False
# 799    False
# Name: Type 1, Length: 800, dtype: bool

# %%
df["Type 2"] == "Electric"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Name: Type 2, Length: 800, dtype: bool

# %%
df.groupby(["Type 1"]).count()
# Out:
#             #  Name  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Bug        69    69      52   69      69       69       69       69     69
# Dark       31    31      21   31      31       31       31       31     31
# Dragon     32    32      21   32      32       32       32       32     32
# Electric   44    44      17   44      44       44       44       44     44
# Fairy      17    17       2   17      17       17       17       17     17
# Fighting   27    27       7   27      27       27       27       27     27
# Fire       52    52      24   52      52       52       52       52     52
# Flying      4     4       2    4       4        4        4        4      4
# Ghost      32    32      22   32      32       32       32       32     32
# Grass      70    70      37   70      70       70       70       70     70
# Ground     32    32      19   32      32       32       32       32     32
# ...

# %%
df.groupby(["Type 1","Type 2"]).count()
# Out:
#                   #  Name  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1 Type 2
# Bug    Electric   2     2   2       2        2        2        2      2
#        Fighting   2     2   2       2        2        2        2      2
#        Fire       2     2   2       2        2        2        2      2
#        Flying    14    14  14      14       14       14       14     14
#        Ghost      1     1   1       1        1        1        1      1
# ...              ..   ...  ..     ...      ...      ...      ...    ...
# Water  Ice        3     3   3       3        3        3        3      3
#        Poison     3     3   3       3        3        3        3      3
#        Psychic    5     5   5       5        5        5        5      5
#        Rock       4     4   4       4        4        4        4      4
#        Steel      1     1   1       1        1        1        1      1
#
#                  Generation  Legendary
# Type 1 Type 2
# ...

# %%
# Find pockemon Where type 1 is water and Type 2 is ice
df[(df["Type 1"] == "Water") & (df["Type 2"] == "Ice")]
# Out:
#        #      Name Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 94    87   Dewgong  Water    Ice   90      70       80       70       95
# 98    91  Cloyster  Water    Ice   50      95      180       85       45
# 142  131    Lapras  Water    Ice  130      85       80       85       95
#
#      Speed  Generation  Legendary
# 94      70           1      False
# 98      70           1      False
# 142     60           1      False

# %%
# Find a pockemon where speed and attack is maximum
df[(df["Attack"] > 170) & (df["Speed"] > 140)]
# Out:
#        #                Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 429  386  DeoxysAttack Forme  Psychic    NaN  50     180       20      180
#
#      Sp. Def  Speed  Generation  Legendary
# 429       20    150           3       True
